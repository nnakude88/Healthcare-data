# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import mpl_toolkits
#from mpl_toolkits.basemap import Basemap
from matplotlib import cm

import seaborn as sns
sns.set(style="white", palette="muted", color_codes=True)
import pandas as pd
pd.options.mode.chained_assignment = None 
import numpy as np
from haversine import haversine
from bokeh.io import output_notebook,show
from bokeh.models import HoverTool
from bokeh.plotting import figure
from bokeh.palettes import Spectral4

# %%
hc = pd.read_excel("healthcare_dataset.xlsx")
hc
# Out:
#                       Name  Age  Gender Blood Type Medical Condition  \
# 0          Tiffany Ramirez   81  Female         O-          Diabetes
# 1              Ruben Burns   35    Male         O+            Asthma
# 2                Chad Byrd   61    Male         B-           Obesity
# 3        Antonio Frederick   49    Male         B-            Asthma
# 4      Mrs. Brandy Flowers   51    Male         O-         Arthritis
# ...                    ...  ...     ...        ...               ...
# 9995            James Hood   83    Male         A+           Obesity
# 9996       Stephanie Evans   47  Female        AB+         Arthritis
# 9997  Christopher Martinez   54    Male         B-         Arthritis
# 9998           Amanda Duke   84    Male         A+         Arthritis
# 9999             Eric King   20    Male         B-         Arthritis
#
#      Date of Admission             Doctor                   Hospital  \
# ...

# %%
hc.dtypes
# Out:
# Name                          object
# Age                            int64
# Gender                        object
# Blood Type                    object
# Medical Condition             object
# Date of Admission     datetime64[ns]
# Doctor                        object
# Hospital                      object
# Insurance Provider            object
# Billing Amount               float64
# Room Number                    int64
# Admission Type                object
# Discharge Date        datetime64[ns]
# Medication                    object
# Test Results                  object
# dtype: object

# %%
hc.describe
# Out:
# <bound method NDFrame.describe of                       Name  Age  Gender Blood Type Medical Condition  \
# 0          Tiffany Ramirez   81  Female         O-          Diabetes
# 1              Ruben Burns   35    Male         O+            Asthma
# 2                Chad Byrd   61    Male         B-           Obesity
# 3        Antonio Frederick   49    Male         B-            Asthma
# 4      Mrs. Brandy Flowers   51    Male         O-         Arthritis
# ...                    ...  ...     ...        ...               ...
# 9995            James Hood   83    Male         A+           Obesity
# 9996       Stephanie Evans   47  Female        AB+         Arthritis
# 9997  Christopher Martinez   54    Male         B-         Arthritis
# 9998           Amanda Duke   84    Male         A+         Arthritis
# 9999             Eric King   20    Male         B-         Arthritis
#
#      Date of Admission             Doctor                   Hospital  \
# ...

# %%
hc.shape
# Out:
# (10000, 15)

# %%
hc.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Length: 10000, dtype: bool

# %%
hc.isnull().sum()
# Out:
# Name                  0
# Age                   0
# Gender                0
# Blood Type            0
# Medical Condition     0
# Date of Admission     0
# Doctor                0
# Hospital              0
# Insurance Provider    0
# Billing Amount        0
# Room Number           0
# Admission Type        0
# Discharge Date        0
# Medication            0
# Test Results          0
# dtype: int64

# %%
hc.columns
# Out:
# Index(['Name', 'Age', 'Gender', 'Blood Type', 'Medical Condition',
#        'Date of Admission', 'Doctor', 'Hospital', 'Insurance Provider',
#        'Billing Amount', 'Room Number', 'Admission Type', 'Discharge Date',
#        'Medication', 'Test Results'],
#       dtype='object')

# %% [markdown]
# ## VISUALIZATION

# %%
import pandas as pd
import plotly.express as px
import seaborn as sns

# Load the dataset
hc = pd.read_excel("healthcare_dataset.xlsx")

# Create a vibrant color palette
colors = sns.color_palette("husl", 8).as_hex()

# Create an interactive histogram for Age
fig = px.histogram(hc, x='Age', nbins=20, title='Age Distribution',
                   color_discrete_sequence=[colors[0]])

# Show the interactive plot
fig.show()

# %%
import plotly.express as px

# Prepare the data by counting the values
medical_condition_data = hc['Medical Condition'].value_counts().reset_index()
medical_condition_data.columns = ['Medical Condition', 'Count']  # Rename columns appropriately

# Create an interactive bar chart for Medical Condition distribution
fig = px.bar(medical_condition_data,
             x='Medical Condition', y='Count', 
             title='Medical Condition Distribution',
             labels={'Medical Condition': 'Medical Condition', 'Count': 'Count'},
             color='Count',  # Color by the count of each medical condition
             color_continuous_scale=px.colors.sequential.Plasma)  # Color scale

# Show the interactive plot
fig.show()

# %%
import plotly.express as px

# Prepare the data
gender_counts = hc['Gender'].value_counts().reset_index()
gender_counts.columns = ['Gender', 'Count']

# Create an interactive pie chart for Gender distribution
fig = px.pie(gender_counts, 
             names='Gender', 
             values='Count', 
             title='Gender Distribution',
             color_discrete_sequence=colors)

# Show the interactive plot
fig.show()

# %%
import plotly.express as px

# Prepare the data by counting the values
blood_type_data = hc['Blood Type'].value_counts().reset_index()
blood_type_data.columns = ['Blood Type', 'Count']  # Rename columns appropriately

# Create an interactive bar chart for Blood Type distribution
fig = px.bar(blood_type_data,
             x='Blood Type', y='Count', 
             title='Blood Type Distribution',
             labels={'Blood Type': 'Blood Type', 'Count': 'Count'},
             color='Count',  # Color by the count of each blood type
             color_continuous_scale=px.colors.sequential.Viridis)  # Color scale

# Show the interactive plot
fig.show()

# %%
import plotly.express as px

# Prepare data by counting the values
insurance_data = hc['Insurance Provider'].value_counts().reset_index()
insurance_data.columns = ['Insurance Provider', 'count']  # Rename columns appropriately

# Create an interactive bar chart for Insurance Provider frequency
fig = px.bar(insurance_data,
             x='Insurance Provider', y='count', 
             title='Insurance Provider Frequency',
             labels={'Insurance Provider': 'Insurance Provider', 'count': 'Count'},
             color_discrete_sequence=px.colors.qualitative.Pastel)

# Show the interactive plot
fig.show()

# %%
import plotly.express as px

# Create an interactive histogram for Billing Amount
fig = px.histogram(hc, x='Billing Amount', nbins=20, title='Billing Amount Distribution',
                   color_discrete_sequence=px.colors.qualitative.Vivid, 
                   marginal='box')  # Adding box plot for distribution insights

# Show the interactive plot
fig.show()

# %%
import plotly.express as px

# Prepare the data by counting the values
admission_data = hc['Admission Type'].value_counts().reset_index()
admission_data.columns = ['Admission Type', 'count']  # Rename columns appropriately

# Create an interactive bar chart for Admission Type frequency
fig = px.bar(admission_data,
             x='Admission Type', y='count', 
             title='Admission Type Frequency',
             labels={'Admission Type': 'Admission Type', 'count': 'Count'},
             color_discrete_sequence=px.colors.qualitative.Pastel)

# Show the interactive plot
fig.show()

# %%
import plotly.express as px

# Prepare the data by counting the values
medication_data = hc['Medication'].value_counts().reset_index()
medication_data.columns = ['Medication', 'count']  # Rename columns appropriately

# Create an interactive bar chart for Medication frequency
fig = px.bar(medication_data,
             x='Medication', y='count', 
             title='Medication Frequency',
             labels={'Medication': 'Medication', 'count': 'Count'},
             color_discrete_sequence=px.colors.qualitative.Pastel)

# Show the interactive plot
fig.show()

# %%
import plotly.express as px

# Prepare the data by counting the values
test_results_data = hc['Test Results'].value_counts().reset_index()
test_results_data.columns = ['Test Results', 'count']  # Rename columns appropriately

# Create an interactive bar chart for Test Results frequency
fig = px.bar(test_results_data,
             x='Test Results', y='count', 
             title='Test Results Frequency',
             labels={'Test Results': 'Test Results', 'count': 'Count'},
             color_discrete_sequence=px.colors.qualitative.Set2)

# Show the interactive plot
fig.show()

# %%
# 2. Box Plot: Billing Amount by Medical Condition
fig2 = px.box(hc, x='Medical Condition', y='Billing Amount', color='Medical Condition',
               title='Billing Amount Distribution by Medical Condition',
               labels={'Medical Condition': 'Medical Condition', 'Billing Amount': 'Billing Amount'},
               color_discrete_sequence=px.colors.qualitative.Set1)
fig2.show()

# %%
#  Bar Chart: Average Billing Amount by Insurance Provider
avg_billing = hc.groupby('Insurance Provider')['Billing Amount'].mean().reset_index()
fig5 = px.bar(avg_billing, x='Insurance Provider', y='Billing Amount',
               title='Average Billing Amount by Insurance Provider',
               labels={'Insurance Provider': 'Insurance Provider', 'Billing Amount': 'Average Billing Amount'},
               color='Billing Amount', 
               color_continuous_scale=px.colors.sequential.Viridis)
fig5.show()

# %%
import pandas as pd
import plotly.express as px

# Load the dataset
hc = pd.read_excel("healthcare_dataset.xlsx")

# Create a box plot for Age by Medical Condition
fig_box = px.box(hc, x='Medical Condition', y='Age', 
                  title='Age Distribution by Medical Condition',
                  labels={'Medical Condition': 'Medical Condition', 'Age': 'Age'},
                  color='Medical Condition',  # Color by Medical Condition
                  color_discrete_sequence=px.colors.qualitative.Set2)

# Show the interactive plot
fig_box.show()

# %%
import pandas as pd
import plotly.express as px

# Load the dataset
hc = pd.read_excel("healthcare_dataset.xlsx")

# Create a bar chart for Medication by Gender
fig_bar = px.histogram(hc, x='Medication', color='Gender', 
                        title='Medication Distribution by Gender',
                        labels={'Medication': 'Medication', 'Gender': 'Gender'},
                        barmode='group',  # Group bars for better comparison
                        color_discrete_sequence=px.colors.qualitative.Set2)

# Show the interactive plot
fig_bar.show()

# %%
import pandas as pd
import plotly.express as px

# Load the dataset
hc = pd.read_excel("healthcare_dataset.xlsx")

# Count the number of admissions per hospital
admissions_count = hc['Hospital'].value_counts().reset_index()
admissions_count.columns = ['Hospital', 'Number of Admissions']

# Get the top 10 hospitals with the most admissions
top_10_hospitals = admissions_count.nlargest(10, 'Number of Admissions')

# Create a bar chart for the top 10 hospitals
fig_bar = px.bar(top_10_hospitals, x='Hospital', y='Number of Admissions',
                  title='Top 10 Hospitals with Most Admissions',
                  labels={'Hospital': 'Hospital', 'Number of Admissions': 'Total Admissions'},
                  color='Number of Admissions',  # Color by number of admissions
                  color_continuous_scale=px.colors.sequential.Viridis)

# Show the interactive plot
fig_bar.show()

# %%
import pandas as pd
import plotly.express as px

# Load the dataset
hc = pd.read_excel("healthcare_dataset.xlsx")

# Count the number of admissions per insurance provider
insurance_count = hc['Insurance Provider'].value_counts().reset_index()
insurance_count.columns = ['Insurance Provider', 'Number of Admissions']

# Get the top 10 insurance providers with the most admissions
top_10_insurance = insurance_count.nlargest(10, 'Number of Admissions')

# Create a bar chart for the top 10 insurance providers
fig_bar = px.bar(top_10_insurance, x='Insurance Provider', y='Number of Admissions',
                  title='Top 10 Insurance Providers with Most Admissions',
                  labels={'Insurance Provider': 'Insurance Provider', 'Number of Admissions': 'Total Admissions'},
                  color='Number of Admissions',  # Color by number of admissions
                  color_continuous_scale=px.colors.sequential.Viridis)

# Show the interactive plot
fig_bar.show()

# %%
import pandas as pd
import plotly.express as px

# Load the dataset
hc = pd.read_excel("healthcare_dataset.xlsx")

# Create a new DataFrame for the counts of Medical Condition by Test Results
count_data = hc.groupby(['Test Results', 'Medical Condition']).size().reset_index(name='Count')

# Create a bar chart
fig_bar = px.bar(count_data, 
                  x='Test Results', 
                  y='Count', 
                  color='Medical Condition',  # Color by Medical Condition
                  title='Medical Condition by Test Results',
                  labels={'Test Results': 'Test Results', 'Count': 'Count'},
                  barmode='group',  # Group bars for better comparison
                  color_discrete_sequence=px.colors.qualitative.Set2)

# Show the interactive plot
fig_bar.show()
